# %% [markdown]
# # Deliverable -1

# %% [markdown]
# ## a. Univariate analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns  
from sklearn.model_selection  import train_test_split

# %%
concrete_data = pd.read_csv('concrete.csv')
concrete_data.head()
# Out:
#    cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0   141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1   168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2   250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3   266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4   154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
#
#    strength
# 0     29.89
# 1     23.51
# 2     29.22
# 3     45.85
# 4     18.29

# %%
concrete_data.describe()
# Out:
#             cement         slag          ash        water  superplastic  \
# count  1030.000000  1030.000000  1030.000000  1030.000000   1030.000000
# mean    281.167864    73.895825    54.188350   181.567282      6.204660
# std     104.506364    86.279342    63.997004    21.354219      5.973841
# min     102.000000     0.000000     0.000000   121.800000      0.000000
# 25%     192.375000     0.000000     0.000000   164.900000      0.000000
# 50%     272.900000    22.000000     0.000000   185.000000      6.400000
# 75%     350.000000   142.950000   118.300000   192.000000     10.200000
# max     540.000000   359.400000   200.100000   247.000000     32.200000
#
#          coarseagg      fineagg          age     strength
# count  1030.000000  1030.000000  1030.000000  1030.000000
# mean    972.918932   773.580485    45.662136    35.817961
# std      77.753954    80.175980    63.169912    16.705742
# min     801.000000   594.000000     1.000000     2.330000
# ...

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %%
concrete_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
# cement          1030 non-null float64
# slag            1030 non-null float64
# ash             1030 non-null float64
# water           1030 non-null float64
# superplastic    1030 non-null float64
# coarseagg       1030 non-null float64
# fineagg         1030 non-null float64
# age             1030 non-null int64
# strength        1030 non-null float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
# number of missing values (only the ones recognised as missing values) in each of the attributes
pd.DataFrame( concrete_data.isnull().sum(), columns= ['Number of missing values'])
# Out:
#               Number of missing values
# cement                               0
# slag                                 0
# ash                                  0
# water                                0
# superplastic                         0
# coarseagg                            0
# fineagg                              0
# age                                  0
# strength                             0

# %%
concrete_data.describe() # the output results provide the five number summary of the data.
# Out:
#             cement         slag          ash        water  superplastic  \
# count  1030.000000  1030.000000  1030.000000  1030.000000   1030.000000
# mean    281.167864    73.895825    54.188350   181.567282      6.204660
# std     104.506364    86.279342    63.997004    21.354219      5.973841
# min     102.000000     0.000000     0.000000   121.800000      0.000000
# 25%     192.375000     0.000000     0.000000   164.900000      0.000000
# 50%     272.900000    22.000000     0.000000   185.000000      6.400000
# 75%     350.000000   142.950000   118.300000   192.000000     10.200000
# max     540.000000   359.400000   200.100000   247.000000     32.200000
#
#          coarseagg      fineagg          age     strength
# count  1030.000000  1030.000000  1030.000000  1030.000000
# mean    972.918932   773.580485    45.662136    35.817961
# std      77.753954    80.175980    63.169912    16.705742
# min     801.000000   594.000000     1.000000     2.330000
# ...

# %%
mean=concrete_data['cement'].mean()
median=concrete_data['cement'].median()
mode=concrete_data['cement'].mode()

print('Mean: ',mean,'\nMedian: ',median,'\nMode: ',mode[0])

plt.figure(figsize=(10,5)) # set the figure size
plt.hist(concrete_data['cement'],bins=100,color='lightblue') #Plot the histogram

plt.axvline(mean,color='green',label='Mean')     
plt.axvline(median,color='blue',label='Median')
plt.axvline(mode[0],color='red',label='Mode')

plt.xlabel('cement')         # label the x-axis
plt.ylabel('Frequency')   # label the y-axis
plt.legend()              # Plot the legend
plt.show()
# Out:
# Mean:  281.1678640776698
# Median:  272.9
# Mode:  362.6

# %% [markdown]
# * The distribution of 'cement' is normal distribution

# %%
mean=concrete_data['slag'].mean()
median=concrete_data['slag'].median()
mode=concrete_data['slag'].mode()

print('Mean: ',mean,'\nMedian: ',median,'\nMode: ',mode[0])

plt.figure(figsize=(10,5)) # set the figure size
plt.hist(concrete_data['slag'],bins=100,color='lightblue') #Plot the histogram

plt.axvline(mean,color='green',label='Mean')     
plt.axvline(median,color='blue',label='Median')
plt.axvline(mode[0],color='red',label='Mode')

plt.xlabel('slag')         # label the x-axis
plt.ylabel('Frequency')   # label the y-axis
plt.legend()              # Plot the legend
plt.show()
# Out:
# Mean:  73.89582524271844
# Median:  22.0
# Mode:  0.0

# %% [markdown]
# * Right Skewed distribution for 'Slag' variable

# %%
mean=concrete_data['ash'].mean()
median=concrete_data['ash'].median()
mode=concrete_data['ash'].mode()

print('Mean: ',mean,'\nMedian: ',median,'\nMode: ',mode[0])

plt.figure(figsize=(10,5)) # set the figure size
plt.hist(concrete_data['ash'],bins=100,color='lightblue') #Plot the histogram

plt.axvline(mean,color='green',label='Mean')     
plt.axvline(median,color='blue',label='Median')
plt.axvline(mode[0],color='red',label='Mode')

plt.xlabel('ash')         # label the x-axis
plt.ylabel('Frequency')   # label the y-axis
plt.legend()              # Plot the legend
plt.show()
# Out:
# Mean:  54.188349514563086
# Median:  0.0
# Mode:  0.0

# %% [markdown]
# * The distribution for 'ash' is right skewed

# %%
mean=concrete_data['water'].mean()
median=concrete_data['water'].median()
mode=concrete_data['water'].mode()

print('Mean: ',mean,'\nMedian: ',median,'\nMode: ',mode[0])

plt.figure(figsize=(10,5)) # set the figure size
plt.hist(concrete_data['water'],bins=100,color='lightblue') #Plot the histogram

plt.axvline(mean,color='green',label='Mean')     
plt.axvline(median,color='blue',label='Median')
plt.axvline(mode[0],color='red',label='Mode')

plt.xlabel('water')         # label the x-axis
plt.ylabel('Frequency')   # label the y-axis
plt.legend()              # Plot the legend
plt.show()
# Out:
# Mean:  181.56728155339798
# Median:  185.0
# Mode:  192.0

# %% [markdown]
# * The distribution for 'water' is normal distribution

# %%
mean=concrete_data['superplastic'].mean()
median=concrete_data['superplastic'].median()
mode=concrete_data['superplastic'].mode()

print('Mean: ',mean,'\nMedian: ',median,'\nMode: ',mode[0])

plt.figure(figsize=(10,5)) # set the figure size
plt.hist(concrete_data['superplastic'],bins=100,color='lightblue') #Plot the histogram

plt.axvline(mean,color='green',label='Mean')     
plt.axvline(median,color='blue',label='Median')
plt.axvline(mode[0],color='red',label='Mode')

plt.xlabel('superplastic')         # label the x-axis
plt.ylabel('Frequency')   # label the y-axis
plt.legend()              # Plot the legend
plt.show()
# Out:
# Mean:  6.204660194174756
# Median:  6.4
# Mode:  0.0

# %% [markdown]
# * The distribution for 'superplastic' is right skewed

# %%
mean=concrete_data['coarseagg'].mean()
median=concrete_data['coarseagg'].median()
mode=concrete_data['coarseagg'].mode()

print('Mean: ',mean,'\nMedian: ',median,'\nMode: ',mode[0])

plt.figure(figsize=(10,5)) # set the figure size
plt.hist(concrete_data['coarseagg'],bins=100,color='lightblue') #Plot the histogram

plt.axvline(mean,color='green',label='Mean')     
plt.axvline(median,color='blue',label='Median')
plt.axvline(mode[0],color='red',label='Mode')

plt.xlabel('coarseagg')         # label the x-axis
plt.ylabel('Frequency')   # label the y-axis
plt.legend()              # Plot the legend
plt.show()
# Out:
# Mean:  972.918932038835
# Median:  968.0
# Mode:  932.0

# %% [markdown]
# * the distribution for 'coarseagg' is normal

# %%
mean=concrete_data['fineagg'].mean()
median=concrete_data['fineagg'].median()
mode=concrete_data['fineagg'].mode()

print('Mean: ',mean,'\nMedian: ',median,'\nMode: ',mode[0])

plt.figure(figsize=(10,5)) # set the figure size
plt.hist(concrete_data['fineagg'],bins=100,color='lightblue') #Plot the histogram

plt.axvline(mean,color='green',label='Mean')     
plt.axvline(median,color='blue',label='Median')
plt.axvline(mode[0],color='red',label='Mode')

plt.xlabel('fineagg')         # label the x-axis
plt.ylabel('Frequency')   # label the y-axis
plt.legend()              # Plot the legend
plt.show()
# Out:
# Mean:  773.5804854368932
# Median:  779.5
# Mode:  594.0

# %% [markdown]
# * The distribution for 'fineagg' is normal

# %%
mean=concrete_data['age'].mean()
median=concrete_data['age'].median()
mode=concrete_data['age'].mode()

print('Mean: ',mean,'\nMedian: ',median,'\nMode: ',mode[0])

plt.figure(figsize=(10,5)) # set the figure size
plt.hist(concrete_data['age'],bins=100,color='lightblue') #Plot the histogram

plt.axvline(mean,color='green',label='Mean')     
plt.axvline(median,color='blue',label='Median')
plt.axvline(mode[0],color='red',label='Mode')

plt.xlabel('age')         # label the x-axis
plt.ylabel('Frequency')   # label the y-axis
plt.legend()              # Plot the legend
plt.show()
# Out:
# Mean:  45.662135922330094
# Median:  28.0
# Mode:  28

# %% [markdown]
# * The distribution for 'age' is right skewed

# %%
mean=concrete_data['strength'].mean()
median=concrete_data['strength'].median()
mode=concrete_data['strength'].mode()

print('Mean: ',mean,'\nMedian: ',median,'\nMode: ',mode[0])

plt.figure(figsize=(10,5)) # set the figure size
plt.hist(concrete_data['strength'],bins=100,color='lightblue') #Plot the histogram

plt.axvline(mean,color='green',label='Mean')     
plt.axvline(median,color='blue',label='Median')
plt.axvline(mode[0],color='red',label='Mode')

plt.xlabel('strength')         # label the x-axis
plt.ylabel('Frequency')   # label the y-axis
plt.legend()              # Plot the legend
plt.show()
# Out:
# Mean:  35.81796116504854
# Median:  34.445
# Mode:  33.4

# %% [markdown]
# * The distribution for 'strength' is normal

# %% [markdown]
# ### Visualize Outliers using Box plot

# %%
sns.boxplot(x=concrete_data['cement'])   # box plot

# %% [markdown]
# * There dont seem to have outliers for the variable 'cement'

# %%
sns.boxplot(x=concrete_data['slag']) # box plot

# %% [markdown]
# * There is one data points after 350 that is listed as an outlier

# %%
sns.boxplot(x=concrete_data['ash'])

# %% [markdown]
# * There is no outlier for the variable 'ash'

# %%
sns.boxplot(x=concrete_data['water'])

# %% [markdown]
# * There are outliers that lie outside the range 13 to 230 for the variable 'water'

# %%
sns.boxplot(x=concrete_data['superplastic'])

# %% [markdown]
# * There are outliers above 25 for the variable 'superplastic'

# %%
sns.boxplot(x=concrete_data['coarseagg'])

# %% [markdown]
# * There is no outlier for the variable 'coarseagg'

# %%
sns.boxplot(x=concrete_data['fineagg'])

# %% [markdown]
# * The is an outliers after the data point 950 for the variable 'fineagg'

# %%
sns.boxplot(x=concrete_data['age'])

# %% [markdown]
# * There are several outlier beyond 125 for the variable 'age'

# %%
sns.boxplot(x=concrete_data['strength'])

# %% [markdown]
# * There are outliers beyond 77 for the variable 'strength'

# %% [markdown]
# ## b. Multivariate analysis

# %%
sns.pairplot(concrete_data, diag_kind='kde') 
plt.suptitle('Pair Plot of concrete data', 
             size = 20);# plots scatter plots for every pair of attributes and histograms along the diagonal
plt.show()

# %% [markdown]
# * There seems to have positive correlation between 'cement', 'age', 'water' with 'strength'
# * Not much significant correlation can be drawn from 'coarseagg' and 'fineagg'

# %% [markdown]
# ## c. Pick one strategy to address the presence outliers and missing values and perform necessary imputation

# %%
concrete_data = concrete_data.replace('?', np.nan)

# %%
#instead of dropping the rows, lets replace the missing values with median value. 
concrete_data.median()
# Out:
# cement          272.900
# slag             22.000
# ash               0.000
# water           185.000
# superplastic      6.400
# coarseagg       968.000
# fineagg         779.500
# age              28.000
# strength         34.445
# dtype: float64

# %%
# replace the missing values with median value.
# Note, we do not need to specify the column names below
# every column's missing value is replaced with that column's median respectively  (axis =0 means columnwise)

medianFiller = lambda x: x.fillna(x.median())
concrete_data = concrete_data.apply(medianFiller,axis=0)

# %%
concrete_data.head(10)
# Out:
#    cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0   141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1   168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2   250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3   266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4   154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
# 5   255.0    0.0    0.0  192.0           0.0      889.8    945.0   90
# 6   166.8  250.2    0.0  203.5           0.0      975.6    692.6    7
# 7   251.4    0.0  118.3  188.5           6.4     1028.4    757.7   56
# 8   296.0    0.0    0.0  192.0           0.0     1085.0    765.0   28
# 9   155.0  184.0  143.0  194.0           9.0      880.0    699.0   28
#
#    strength
# 0     29.89
# 1     23.51
# 2     29.22
# 3     45.85
# 4     18.29
# 5     21.86
# 6     15.75
# 7     36.64
# 8     21.65
# 9     28.99

# %% [markdown]
# # Deliverable -2

# %% [markdown]
# ## a. Identify opportunities (if any) to create a composite feature, drop a feature

# %%
from scipy.stats import zscore
concrete_df_z = concrete_data.apply(zscore)
# coarseagg and fineagg variable shows a weak correlation , hence droping them

#array = concrete_data_z.values

# %%
y = concrete_df_z[['strength']]
X = concrete_df_z.drop(labels= "strength" , axis = 1)
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= .30, random_state=1)

# %%
dt_model = DecisionTreeRegressor()

# %%
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
print (pd.DataFrame(dt_model.feature_importances_, columns = ["Imp"], index = X_train.columns))
# Out:
#                    Imp
# cement        0.351051
# slag          0.095224
# ash           0.012355
# water         0.123153
# superplastic  0.019977
# coarseagg     0.032756
# fineagg       0.031912
# age           0.333572

# %%
dt_model.score(X_test, y_test)
# Out:
# 0.8586157935780574

# %%
dt_model.score(X_train, y_train)
# Out:
# 0.9948592395522299

# %%
## drop useless columns based on Feature importance

# %%
drop_cols = ['ash' , 'coarseagg' , 'fineagg' , 'superplastic' , 'strength']

X = concrete_df_z.drop(labels= drop_cols , axis = 1)
y = concrete_df_z[['strength']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.30, random_state=1)

# %%
dt_model = DecisionTreeRegressor()

# %%
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
print (pd.DataFrame(dt_model.feature_importances_, columns = ["Imp"], index = X_train.columns))
# Out:
#              Imp
# cement  0.389570
# slag    0.115213
# water   0.158217
# age     0.337000

# %%
dt_model.score(X_test, y_test)
# Out:
# 0.852065944945633

# %%
dt_model.score(X_train, y_train)
# Out:
# 0.993459432259283

# %% [markdown]
# * After removing the useless columns, we dont see much change in term of accuracy of the model

# %% [markdown]
# ## b. Decide on complexity of the model, should it be simple linear model in terms of parameters or would a quadratic or higher degree help

# %% [markdown]
# ### Adding interaction terms

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model

poly = PolynomialFeatures(degree=2, interaction_only=True)
X_train2 = poly.fit_transform(X_train)
X_test2 = poly.fit_transform(X_test)

poly_clf = linear_model.LinearRegression()

poly_clf.fit(X_train2, y_train)

y_pred = poly_clf.predict(X_test2)

#print(y_pred)

#In sample (training) R^2 will always improve with the number of variables!
print(poly_clf.score(X_train2, y_train))
# Out:
# 0.7549578268848258

# %%
#Out off sample (testing) R^2 is our measure of sucess and does improve
print(poly_clf.score(X_test2, y_test))
# Out:
# 0.7444710081439014

# %%
# but this improves as the cost of 29 extra variables!
print(X_train.shape)
print(X_train2.shape)
# Out:
# (721, 8)
# (721, 37)

# %% [markdown]
# Polynomial Features (with only interaction terms) have improved the Out of sample R^2. However at the cost of increaing the number of variables significantly.

# %% [markdown]
# ## c. Explore for gaussians. If data is likely to be a mix of gaussians, explore individual clusters and present your findings in terms of the independent attributes and their suitability to predict strength

# %%
from sklearn.cluster import KMeans


cluster_range = range( 1, 15 )
cluster_errors = []
for num_clusters in cluster_range:
  clusters = KMeans( num_clusters, n_init = 10 )
  clusters.fit(concrete_data_z)
  labels = clusters.labels_
  centroids = clusters.cluster_centers_
  cluster_errors.append( clusters.inertia_ )
clusters_df = pd.DataFrame( { "num_clusters":cluster_range, "cluster_errors": cluster_errors } )
clusters_df[0:15]
# Out:
#     num_clusters  cluster_errors
# 0              1     7210.000000
# 1              2     5609.730976
# 2              3     4443.145549
# 3              4     3655.592130
# 4              5     3017.168717
# 5              6     2744.385571
# 6              7     2551.153404
# 7              8     2361.684691
# 8              9     2197.917083
# 9             10     2057.639811
# 10            11     1937.505977
# 11            12     1853.606493
# 12            13     1747.729892
# 13            14     1695.418579

# %%
# Elbow plot

plt.figure(figsize=(12,6))
plt.plot( clusters_df.num_clusters, clusters_df.cluster_errors, marker = "o" )

# %%
# The elbow plot confirms our visual analysis that there are likely 6 good clusters
# Let us start with 6 clusters

# %%
#kmeans = KMeans(n_clusters= 5, random_state=2345)
kmeans = KMeans(n_clusters= 6)
kmeans.fit(concrete_df_z)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=6, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels = kmeans.labels_
counts = np.bincount(labels[labels>=0])
print(counts)
# Out:
# [173 198 279 189 135  56]

# %%
## creating a new dataframe only for labels and converting it into categorical variable
cluster_labels = pd.DataFrame(kmeans.labels_ , columns = list(['labels']))
cluster_labels['labels'] = cluster_labels['labels'].astype('category')
concrete_df_labeled = concrete_data.join(cluster_labels)


concrete_df_labeled.boxplot(by = 'labels',  layout=(3,3), figsize=(30, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000017D56CA5988>,
# ...
#       dtype=object)

# %%
centroids = cluster.cluster_centers_
centroids
# Out:
# array([[ 5.54487698e-01, -7.16880780e-02, -1.37360564e-01,
#          6.02944680e-02, -6.60314725e-03, -3.50802012e-01,
#         -6.71671566e-01,  5.09902022e-01,  8.45010055e-01],
#        [-4.01644426e-01,  3.23418504e-02, -1.37360564e-01,
#         -4.47177666e-03,  1.21216012e-02,  2.13767170e-01,
#          4.98433312e-01, -3.91901821e-01, -6.60140471e-01],
#        [-7.03884264e-01,  6.78570283e-01,  7.28010989e+00,
#         -1.25261946e+00, -2.11775648e-01,  1.65543118e+00,
#          4.95446667e-01,  2.93081332e-02,  3.68982864e-01]])

# %%
# There are many outliers on each dimension  (indicated by the black circles)
# Spread of data on each dimension (indivated by the whiskers is long ... due to the outliers)
# If the outliers are addressed, the clusters will overlap much less than right now (except in year dimension which has no outlier)

# %%
#No distinct clusters are visible at any number of clusters. Looks like the attributes are weak predictors except for cement. 
# The potential of getting better results by breaking data into clusters is unlikely to give the desired result

# %% [markdown]
# # Deliverable -3

# %% [markdown]
# ## a. Obtain feature importance for the individual features and present your findings

# %% [markdown]
# ###  separate independent and dependent variables

# %%
# Copy all the predictor variables into X dataframe. Since 'strength' is dependent variable drop it
X = concrete_data.drop('strength', axis=1)

# Copy the 'strength' column alone into the y dataframe. This is the dependent variable
y = concrete_data[['strength']]

# %%
from sklearn import preprocessing

# scale all the columns of the mpg_df. This will produce a numpy array
X_scaled = preprocessing.scale(X)
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)  # ideally the training and test should be 

y_scaled = preprocessing.scale(y)
y_scaled = pd.DataFrame(y_scaled, columns=y.columns)  # ideally the training and test should be

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.30, random_state=1)

# %% [markdown]
# ### Fit Linear Model

# %%
from sklearn.linear_model import LinearRegression
import numpy as np 
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
intercept = regression_model.intercept_[0]

print("The intercept for our model is {}".format(intercept))
# Out:
# The intercept for our model is -0.013041400221605257

# %% [markdown]
# ### Create a regularized RIDGE model and note the coefficients

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=.3)
ridge.fit(X_train,y_train)
print ("Ridge model:", (ridge.coef_))
# Out:
# Ridge model: [[ 0.78652136  0.55696657  0.34291358 -0.13534196  0.13450497  0.10831507
#    0.16918324  0.41713594]]

# %% [markdown]
# # Create a regularized LASSO model and note the coefficients

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha=0.1)
lasso.fit(X_train,y_train)
print ("Lasso model:", (lasso.coef_))

# Observe, many of the coefficients have become 0 indicating drop of those dimensions from the model
# Out:
# Lasso model: [ 0.39456594  0.14777481  0.         -0.11823668  0.19361099 -0.
#  -0.          0.2543608 ]

# %% [markdown]
# ## Let us compare their scores

# %%
print(regression_model.score(X_train, y_train))
print(regression_model.score(X_test, y_test))
# Out:
# 0.6031487540630229
# 0.6339136715208276

# %%
print(ridge.score(X_train, y_train))
print(ridge.score(X_test, y_test))
# Out:
# 0.603144790939098
# 0.6340333563625518

# %%
print(lasso.score(X_train, y_train))
print(lasso.score(X_test, y_test))
# Out:
# 0.5215627623725142
# 0.51856614888699

# %% [markdown]
# * More or less similar results but with less complex models.  Complexity is a function of variables and coefficients
# * Note - with Ridge, we get equally good result in test though not so in training.

# %% [markdown]
# * Based on the lasso coefficients, The features that are significantly important are 'cement', 'slag','water','superplastic','age'

# %% [markdown]
# # Deliverable - 4

# %% [markdown]
# ## a. Algorithms that you think will be suitable for this project

# %% [markdown]
# ### 1. Linear Regression Model

# %%
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
for idx, col_name in enumerate(X_train.columns):
    print("The coefficient for {} is {}".format(col_name, regression_model.coef_[0][idx]))
# Out:
# The coefficient for cement is 0.7917080306678752
# The coefficient for slag is 0.5620608749496462
# The coefficient for ash is 0.34747677102632063
# The coefficient for water is -0.13186138372514944
# The coefficient for superplastic is 0.13449876840644523
# The coefficient for coarseagg is 0.11183689241537578
# The coefficient for fineagg is 0.17370080312287323
# The coefficient for age is 0.4175909779025137

# %%
intercept = regression_model.intercept_[0]
print("The intercept for our model is {}".format(intercept))
# Out:
# The intercept for our model is -0.013041400221605257

# %%
regression_model.score(X_train, y_train)
# Out:
# 0.6031487540630229

# %%
#out of sample score (R^2)

regression_model.score(X_test, y_test)
# Out:
# 0.6339136715208276

# %% [markdown]
# ### 2. Using linear regression with polynomial features

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model

poly = PolynomialFeatures(degree=2, interaction_only=True)
X_train2 = poly.fit_transform(X_train)
X_test2 = poly.fit_transform(X_test)

poly_clf = linear_model.LinearRegression()

poly_clf.fit(X_train2, y_train)

y_pred = poly_clf.predict(X_test2)

#print(y_pred)

#In sample (training) R^2 will always improve with the number of variables!
print(poly_clf.score(X_train2, y_train))
# Out:
# 0.7549578268848258

# %%
#Out off sample (testing) R^2 is our measure of sucess and does improve
print(poly_clf.score(X_test2, y_test))
# Out:
# 0.7444710081439014

# %% [markdown]
# ### 3. Decision Tree Model

# %%
concrete_data.columns
# Out:
# Index(['cement', 'slag', 'ash', 'water', 'superplastic', 'coarseagg',
#        'fineagg', 'age', 'strength'],
#       dtype='object')

# %%
# Import Linear Regression machine learning library
from sklearn.tree import DecisionTreeRegressor

regressor = DecisionTreeRegressor(random_state=0, max_depth=3)

regressor.fit(X_train , y_train)
feature_importances = regressor.feature_importances_


feature_names = concrete_data.columns[0:7]
print(feature_names)

k =7

print(feature_importances)
top_k_idx = (feature_importances.argsort()[-k:][::-1])
# Out:
# Index(['cement', 'slag', 'ash', 'water', 'superplastic', 'coarseagg',
#        'fineagg'],
#       dtype='object')
# [0.46405785 0.         0.         0.08815856 0.         0.
#  0.         0.44778359]

# %%
y_pred = regressor.predict(X_test)

# %%
print(regressor.score(X_train, y_train))
print(regressor.score(X_test, y_test))
# Out:
# 0.6358072763408258
# 0.583104124329016

# %% [markdown]
# Accuracy: 58.3%

# %% [markdown]
# ### 4. Ensemble Techniques....

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, BaggingRegressor
from sklearn import model_selection
from sklearn.utils import resample
from sklearn.metrics import accuracy_score
from sklearn import metrics

# %% [markdown]
# #### Gradient Boosting

# %%
gbmTree = GradientBoostingRegressor(n_estimators=50)
gbmTree.fit(X_train,y_train)
print("gbmTree on training" , gbmTree.score(X_train, y_train))
print("gbmTree on test data ",gbmTree.score(X_test,y_test))
# Out:
# gbmTree on training 0.915342421668803
# gbmTree on test data  0.866167462331877
# C:\Users\Neema MV\Anaconda3\lib\site-packages\sklearn\ensemble\gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# #### Bagging

# %%
bgcl = BaggingRegressor(n_estimators=50, oob_score= True)
bgcl = bgcl.fit(X_train,y_train)
print("bgcl on train data ", bgcl.score(X_train,y_train))
print("bgcl on test data ", bgcl.score(X_test,y_test))
print("out of bag score" , bgcl.oob_score_)
# Out:
# C:\Users\Neema MV\Anaconda3\lib\site-packages\sklearn\ensemble\bagging.py:398: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return column_or_1d(y, warn=True)
# bgcl on train data  0.9812418027882724
# bgcl on test data  0.9048939860513856
# out of bag score 0.8980893731572743

# %% [markdown]
# #### Random Forest

# %%
rfTree = RandomForestRegressor(n_estimators=50)
rfTree.fit(X_train,y_train)
print("rfTree on train data ", rfTree.score(X_train,y_train))
print("rfTree on test data ", rfTree.score(X_test,y_test))
# Out:
# C:\Users\Neema MV\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# rfTree on train data  0.9816027529398471
# rfTree on test data  0.9069046263494033

# %% [markdown]
# ## b. Techniques employed to squeeze that extra performance out of the model without making it overfit or underfit

# %%
# Model Tuning using hyper parameters

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.30, random_state=1)

# %%
from pprint import pprint

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(random_state = 1)

# %%
print('Parameters currently in use:\n')
pprint(rf.get_params())
# Out:
# Parameters currently in use:
#
# {'bootstrap': True,
#  'criterion': 'mse',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 'warn',
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 1,
#  'verbose': 0,
#  'warm_start': False}

# %%
# RandomSearchCV

# %%
import numpy as np
print(np.linspace(start = 5, stop = 10, num = 2))
# Out:
# [ 5. 10.]

# %%
from sklearn.model_selection import RandomizedSearchCV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10 , stop = 15, num = 2)]   # returns evenly spaced 10 numbers
# Number of features to consider at every split
max_features = ['auto', 'log2']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 10, num = 2)]  # returns evenly spaced numbers can be changed to any
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

pprint(random_grid)
# Out:
# {'bootstrap': [True, False],
#  'max_depth': [5, 10, None],
#  'max_features': ['auto', 'log2'],
#  'min_samples_leaf': [1, 2, 4],
#  'min_samples_split': [2, 5, 10],
#  'n_estimators': [10, 15]}

# %%
# Use the random grid to search for best hyperparameters

# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
rf_random = RandomizedSearchCV(estimator=rf, param_distributions=random_grid,
                              n_iter = 5, scoring='neg_mean_absolute_error', 
                              cv = 3, verbose=2, random_state=42, n_jobs=-1,
                              return_train_score=True)

# Fit the random search model
rf_random.fit(X_train, y_train);
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed:   16.8s remaining:   14.7s
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:   16.9s finished
# C:\Users\Neema MV\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:715: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 15,
#  'min_samples_split': 5,
#  'min_samples_leaf': 1,
#  'max_features': 'log2',
#  'max_depth': None,
#  'bootstrap': False}

# %%
best_random = rf_random.best_estimator_   # best ensemble model (with optimal combination of hyperparameters)

# %%
best_random.score(X_test , y_test)
# Out:
# 0.8882696933452411

# %%
# This is the best the randomizedsearchCV could do given the range of values we submitted. It probably got stuck in 
# subobtimal combination of hyper parameters and that is why it's result is lesser than the randomforest regressor earlier

# %%
# GridSearcCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [5,6],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4],
    'min_samples_split': [5,10],
    'n_estimators': [5,6,7]
}

# %%
rf = RandomForestRegressor(random_state = 1)

# %%
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 3, n_jobs = 1, verbose = 0, return_train_score=True)

# %%
# Fit the grid search to the data
grid_search.fit(X_train, y_train);
# Out:
# C:\Users\Neema MV\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Neema MV\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Neema MV\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
grid_search.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 6,
#  'max_features': 3,
#  'min_samples_leaf': 4,
#  'min_samples_split': 10,
#  'n_estimators': 7}

# %%
best_grid = grid_search.best_estimator_
best_grid.score(X_test, y_test)
# Out:
# 0.805146013651073

# %%
# The accuracy is relatively lower as we have severly restricted the hyper parameter ranges. This was done to minimize 
# execution time. The Girdsearch has lower probability of finding the best combination than the randomsearch

# %% [markdown]
# ## c. Model performance range at 95% confidence level

# %%
concrete_XY = X.join(y)

# %%
# configure bootstrap



values = concrete_XY.values

n_iterations = 1000        # Number of bootstrap samples to create
n_size = int(len(concrete_df_z) * 1)    # size of a bootstrap sample

# run bootstrap
stats = list()   # empty list that will hold the scores for each bootstrap iteration
for i in range(n_iterations):

    # prepare train and test sets
	train = resample(values, n_samples=n_size)  # Sampling with replacement 
	test = np.array([x for x in values if x.tolist() not in train.tolist()])  # picking rest of the data not considered in sample
    
    
    # fit model
	gbmTree = GradientBoostingRegressor(n_estimators=50)
	gbmTree.fit(train[:,:-1], train[:,-1])   # fit against independent variables and corresponding target values
	y_test = test[:,-1]    # Take the target column for all rows in test set

    # evaluate model
	predictions = gbmTree.predict(test[:, :-1])   # predict based on independent variables in the test data
	score = gbmTree.score(test[:, :-1] , y_test)

	stats.append(score)

# %%
# plot scores

from matplotlib import pyplot
pyplot.hist(stats)
pyplot.show()
# confidence intervals
alpha = 0.95                             # for 95% confidence 
p = ((1.0-alpha)/2.0) * 100              # tail regions on right and left .25 on each side indicated by P value (border)
lower = max(0.0, np.percentile(stats, p))  
p = (alpha+((1.0-alpha)/2.0)) * 100
upper = min(1.0, np.percentile(stats, p))
print('%.1f confidence interval %.1f%% and %.1f%%' % (alpha*100, lower*100, upper*100))
# Out:
# 95.0 confidence interval 82.8% and 88.0%

# %%
# configure bootstrap




n_iterations = 1000              # Number of bootstrap samples to create
n_size = int(len(concrete_df_z) * 1)    # size of a bootstrap sample

# run bootstrap
stats = list()   # empty list that will hold the scores for each bootstrap iteration

for i in range(n_iterations):

    # prepare train and test sets
	train = resample(values, n_samples=n_size)  # Sampling with replacement
	test = np.array([x for x in values if x.tolist() not in train.tolist()])  # picking rest of the data not considered in sample

    # fit model
	rfTree = RandomForestRegressor(n_estimators=50)  
	rfTree.fit(train[:,:-1], train[:,-1])   # fit against independent variables and corresponding target values

	rfTree.fit(train[:,:-1], train[:,-1])   # fit against independent variables and corresponding target values
	y_test = test[:,-1]    # Take the target column for all rows in test set

    # evaluate model
	predictions = rfTree.predict(test[:, :-1])   # predict based on independent variables in the test data
	score = rfTree.score(test[:, :-1] , y_test)

	stats.append(score)

# %%
# plot scores

from matplotlib import pyplot
pyplot.hist(stats)
pyplot.show()
# confidence intervals
alpha = 0.95                             # for 95% confidence 
p = ((1.0-alpha)/2.0) * 100              # tail regions on right and left .25 on each side indicated by P value (border)
lower = max(0.0, np.percentile(stats, p))  
p = (alpha+((1.0-alpha)/2.0)) * 100
upper = min(1.0, np.percentile(stats, p))
print('%.1f confidence interval %.1f%% and %.1f%%' % (alpha*100, lower*100, upper*100))
# Out:
# 95.0 confidence interval 85.1% and 91.3%
